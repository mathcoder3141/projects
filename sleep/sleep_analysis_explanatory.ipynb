# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
pd.set_option('display.max_columns', 30)
sleep = pd.read_csv('./sleeping-alone-data.csv')

# %%
sleep.head(2)
# Out:
#        StartDate        EndDate  \
# 0            NaN            NaN
# 1  7/10/14 18:37  7/10/14 18:39
#
#   Which of the following best describes your current relationship status?  \
# 0                                           Response
# 1    Single, but cohabiting with a significant other
#
#   How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship.  \
# 0                                           Response
# 1                                          1-5 years
#
#   When both you and your partner are at home, how often do you sleep in separate beds?  \
# 0                                           Response
# 1                                Once a year or less
#
#   When you're not sleeping in the same bed as your partner, where do you typically sleep?  \
# 0                                           Response
# 1                                 On the couch/chair
#
# ...

# %% [markdown]
# It looks like the first row of data is nonsense. So let's go ahead and drop this row.

# %% [markdown]
# # Breakdown of education by gender?

# %%
width = 0.15  # the width of the bars
labels = [gender for gender in sleep['Gender'].unique() if gender is not np.nan]

# bar heights
bachelor = [x for x in sleep[sleep["Education"] == 'Bachelor degree']['Gender'].value_counts()]
graduate = [x for x in sleep[sleep["Education"] == "Graduate degree"]['Gender'].value_counts()]
some_college = [x for x in sleep[sleep["Education"] == "Some college or Associate degree"]['Gender'].value_counts()]
high_shcool = [x for x in sleep[sleep["Education"] == "High school degree"]['Gender'].value_counts()]
no_degree =[x for x in sleep[sleep["Education"] == "Less than high school degree"]['Gender'].value_counts()]

x1 = np.arange(len(bachelor))  # the label locations
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]
x4 = [x + width for x in x3]
x5 = [x + width for x in x4]

plt.bar(x1, graduate, width = width, label = 'Graduate degree')
plt.bar(x2, bachelor, width = width, label = 'Bachelor degree')
plt.bar(x3, some_college, width = width, label = 'Some College  or Assoc degree')
plt.bar(x4, high_shcool, width = width, label = 'Diploma')
plt.bar(x5, no_degree, width = width, label = 'No diploma')
plt.xticks([x + 2 * width for x in range(len(labels))], labels)
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Number of People', fontweight='bold')
plt.title('Highest Level of Education \n By Gender')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# # Household Income by Gender

# %%
low_income = [x for x in sleep[sleep["Household Income"] == "$0 - $24,999"]['Gender'].value_counts()]
low_medium_income = [x for x in sleep[sleep["Household Income"] == "$25,000 - $49,999"]['Gender'].value_counts()]
medium_income = [x for x in sleep[sleep["Household Income"] == "$50,000 - $99,999"]['Gender'].value_counts()]
medium_high_income = [x for x in sleep[sleep["Household Income"] == "$100,000 - $149,999"]['Gender'].value_counts()]
high_income = [x for x in sleep[sleep["Household Income"] == "$150,000+"]['Gender'].value_counts()]

x1 = np.arange(len(low_income))  # the label locations
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]
x4 = [x + width for x in x3]
x5 = [x + width for x in x4]

plt.bar(x1, high_income, width = width, label = '$150,000+')
plt.bar(x2, medium_high_income, width = width, label = '$100,000 - $149,999')
plt.bar(x3, medium_income, width = width, label = '$50,000 - $99,999')
plt.bar(x4, low_medium_income, width = width, label = '$25,000 - $49,999')
plt.bar(x5, low_income, width = width, label = '$0 - $24,999')

plt.xticks([x + 2 * width for x in range(len(labels))], labels)
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Number of People', fontweight='bold')
plt.title('Household Income \n By Gender')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# # Age Group by Gender

# %%
teens = [x for x in sleep[sleep["Age"] == '18-29']['Gender'].value_counts()]
fourties = [x for x in sleep[sleep["Age"] == '45-60']['Gender'].value_counts()]
sixties = [x for x in sleep[sleep["Age"] == '> 60']['Gender'].value_counts()]
thirties = [x for x in sleep[sleep["Age"] == '30-44']['Gender'].value_counts()]

x1 = np.arange(len(teens))  # the label locations
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]
x4 = [x + width for x in x3]

plt.bar(x1, teens, width = width, label = '18-29')
plt.bar(x2, fourties, width = width, label = '45-60')
plt.bar(x3, sixties, width = width, label = '> 60')
plt.bar(x4, thirties, width = width, label = '30-44')

plt.xticks([x + 1.5 * width for x in range(len(x1))], labels)
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Number of People', fontweight='bold')
plt.title('Age By Gender')
plt.legend(loc = 'upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# # Relationship Status

# %%
single = [x for x in sleep[sleep["Which of the following best describes your current relationship status?"] == 'Single, but cohabiting with a significant other']['Gender'].value_counts()]
married = [x for x in sleep[sleep["Which of the following best describes your current relationship status?"] == 'Married']['Gender'].value_counts()]
domestic = [x for x in sleep[sleep["Which of the following best describes your current relationship status?"] == 'In a domestic partnership or civil union']['Gender'].value_counts()]
widowed = [x for x in sleep[sleep["Which of the following best describes your current relationship status?"] == 'Widowed']['Gender'].value_counts()]
separated = [x for x in sleep[sleep["Which of the following best describes your current relationship status?"] == 'Separated']['Gender'].value_counts()]
divorced = [x for x in sleep[sleep["Which of the following best describes your current relationship status?"] == 'Divorced']['Gender'].value_counts()]

# %%
widowed
# Out:
# [1]

# %%
sleep[sleep["Which of the following best describes your current relationship status?"] == 'Widowed']['Gender']
# Out:
# 60      NaN
# 212    Male
# 329     NaN
# Name: Gender, dtype: object

# %% [markdown]
# I was afraid this would happen. Apparently, `widowed` only has one non-null for the gender colum . This would skew our analysis slightly. So for now, we will ignore the `widowed` category.

# %%
x1 = np.arange(len(single))  # the label locations
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]
x4 = [x + width for x in x3]
x5 = [x + width for x in x4]

plt.bar(x1, single, width = width, label = 'Single, but cohabiting with a significant other')
plt.bar(x2, married, width = width, label = 'Married')
plt.bar(x3, domestic, width = width, label = 'In a domestic parnership or civil union')
plt.bar(x4, separated, width = width, label = 'Separated')
plt.bar(x5, divorced, width = width, label = 'Divorced')

plt.xticks([x + 2.5 * width for x in range(len(x1))], labels)
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Number of People', fontweight='bold')
plt.title('Current Relationship Status \n By Gender')
plt.legend(loc = 'upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# # Length in Relationship

# %%
one_to_five = [x for x in sleep[sleep["How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship."] == '1-5 years']['Gender'].value_counts()]
lt_one = [x for x in sleep[sleep["How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship."] == 'Less than 1 year']['Gender'].value_counts()]
gt_twenty = [x for x in sleep[sleep["How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship."] == 'More than 20 years']['Gender'].value_counts()]
six_to_ten = [x for x in sleep[sleep["How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship."] == '6-10 years']['Gender'].value_counts()]
sixteen_to_twenty = [x for x in sleep[sleep["How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship."] == '16-20 years']['Gender'].value_counts()]
eleven_to_fifteen = [x for x in sleep[sleep["How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship."] == '11-15 years']['Gender'].value_counts()]

x1 = np.arange(len(one_to_five))  # the label locations
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]
x4 = [x + width for x in x3]
x5 = [x + width for x in x4]
x6 = [x + width for x in x5]

plt.bar(x1, one_to_five, width = width, label = '1-5 years')
plt.bar(x2, lt_one, width = width, label = 'Less than 1 year')
plt.bar(x3, gt_twenty, width = width, label = 'More than 20 years')
plt.bar(x4, six_to_ten, width = width, label = '6-10 years')
plt.bar(x5, sixteen_to_twenty, width = width, label = '16-20 years')
plt.bar(x6, eleven_to_fifteen, width = width, label = '11-15 years')

plt.xticks([x + 2.5 * width for x in range(len(x1))], labels)
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Number of People', fontweight='bold')
plt.title('Length of Relationship \n By Gender')
plt.legend(loc = 'upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# # You typically sleep

# %% [markdown]
# # Reasons for sleeping in seperate beds

# %% [markdown]
# # Views sleeping in seperate beds v. longevity

# %%
longevity_strong_disagree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"sleeping in separate beds helps us to stay together.\""] == 'Strongly disagree']['Gender'].value_counts()]
longevity_some_disagree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"sleeping in separate beds helps us to stay together.\""] == 'Somewhat disagree']['Gender'].value_counts()]
longevity_some_agree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"sleeping in separate beds helps us to stay together.\""] == 'Neither agree nor disagree']['Gender'].value_counts()]
longevity_neutral = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"sleeping in separate beds helps us to stay together.\""] == 'Somewhat agree']['Gender'].value_counts()]
longevity_strong_agree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"sleeping in separate beds helps us to stay together.\""] == 'Strongly agree']['Gender'].value_counts()]

x1 = np.arange(len(strong_disagree))  # the label locations
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]
x4 = [x + width for x in x3]
x5 = [x + width for x in x4]

plt.bar(x1, longevity_strong_agree, width = width, label = 'Strongly Agree')
plt.bar(x2, longevity_some_agree, width = width, label = 'Somewhat Agree')
plt.bar(x3, longevity_neutral, width = width, label = 'Neither Agree nor Disagree')
plt.bar(x4, longevity_some_disagree, width = width, label = 'Somewhat Disagree')
plt.bar(x5, longevity_strong_disagree, width = width, label = 'Strongly Disagree')

plt.xticks([x + 2.5 * width for x in range(len(x1))], labels)
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Number of People', fontweight='bold')
plt.title('Survey: Sleeping In Seperate Beds Helped Us \n Stay Together By Gender')
plt.legend(loc = 'upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# # Sleeping better

# %%
sleep_better_strong_disagree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"we sleep better when we sleep in separate beds.\""] == 'Strongly disagree']['Gender'].value_counts()]
sleep_better_some_disagree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"we sleep better when we sleep in separate beds.\""] == 'Somewhat disagree']['Gender'].value_counts()]
sleep_better_some_agree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"we sleep better when we sleep in separate beds.\""] == 'Neither agree nor disagree']['Gender'].value_counts()]
sleep_better_neutral = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"we sleep better when we sleep in separate beds.\""] == 'Somewhat agree']['Gender'].value_counts()]
sleep_better_strong_agree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"we sleep better when we sleep in separate beds.\""] == 'Strongly agree']['Gender'].value_counts()]

x1 = np.arange(len(strong_disagree))  # the label locations
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]
x4 = [x + width for x in x3]
x5 = [x + width for x in x4]

plt.bar(x1, sleep_better_strong_agree, width = width, label = 'Strongly Agree')
plt.bar(x2, sleep_better_some_agree, width = width, label = 'Somewhat Agree')
plt.bar(x3, sleep_better_neutral, width = width, label = 'Neither Agree nor Disagree')
plt.bar(x4, sleep_better_some_disagree, width = width, label = 'Somewhat Disagree')
plt.bar(x5, sleep_better_strong_disagree, width = width, label = 'Strongly Disagree')

plt.xticks([x + 2.5 * width for x in range(len(x1))], labels)
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Number of People', fontweight='bold')
plt.title('Survey: Better Sleep From Sleeping \n In Seperate Beds By Gender')
plt.legend(loc = 'upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# # Sex Life Improved

# %%
sex_life_strong_disagree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"our sex life has improved as a result of sleeping in separate beds.\""] == 'Strongly disagree']['Gender'].value_counts()]
sex_life_some_disagree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"our sex life has improved as a result of sleeping in separate beds.\""] == 'Somewhat disagree']['Gender'].value_counts()]
sex_life_some_agree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"our sex life has improved as a result of sleeping in separate beds.\""] == 'Neither agree nor disagree']['Gender'].value_counts()]
sex_life_neutral = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"our sex life has improved as a result of sleeping in separate beds.\""] == 'Somewhat agree']['Gender'].value_counts()]
sex_life_strong_agree = [x for x in sleep[sleep["To what extent do you agree with the following statement: \"our sex life has improved as a result of sleeping in separate beds.\""] == 'Strongly agree']['Gender'].value_counts()]

x1 = np.arange(len(strong_disagree))  # the label locations
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]
x4 = [x + width for x in x3]
x5 = [x + width for x in x4]

plt.bar(x1, sex_life_strong_agree, width = width, label = 'Strongly Agree')
plt.bar(x2, sex_life_some_agree, width = width, label = 'Somewhat Agree')
plt.bar(x3, sex_life_neutral, width = width, label = 'Neither Agree nor Disagree')
plt.bar(x4, sex_life_some_disagree, width = width, label = 'Somewhat Disagree')
plt.bar(x5, sex_life_strong_disagree, width = width, label = 'Strongly Disagree')

plt.xticks([x + 2.5 * width for x in range(len(x1))], labels)
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Number of People', fontweight='bold')
plt.title('Survey: Sex Life Improved From Sleeping \n In Seperate Beds By Gender')
plt.legend(loc = 'upper left', bbox_to_anchor=(1,1))
plt.show()
